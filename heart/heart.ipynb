# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random as rd

# %%
df=pd.read_csv("heart (1).csv")

# %%
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.shape
# Out:
# (303, 14)

# %%
df.isnull().sum()
df.dropna()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
df1=df.loc[1:150,["age","sex","cp","trtbps","chol","fbs","restecg"]]
df1
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg
# 1     37    1   2     130   250    0        1
# 2     41    0   1     130   204    0        0
# 3     56    1   1     120   236    0        1
# 4     57    0   0     120   354    0        1
# 5     57    1   0     140   192    0        1
# ..   ...  ...  ..     ...   ...  ...      ...
# 146   44    0   2     118   242    0        1
# 147   60    0   3     150   240    0        1
# 148   44    1   2     120   226    0        1
# 149   42    1   2     130   180    0        1
# 150   66    1   0     160   228    0        0
#
# [150 rows x 7 columns]

# %%
df2=df.loc[150:300,["thalachh","exng","oldpeak","slp","caa","thall","output"]]
df2
# Out:
#      thalachh  exng  oldpeak  slp  caa  thall  output
# 150       138     0      2.3    2    0      1       1
# 151       125     0      1.6    1    0      2       1
# 152       155     0      0.6    1    0      3       1
# 153       152     0      0.0    1    1      2       1
# 154       152     0      0.0    1    0      2       1
# ..        ...   ...      ...  ...  ...    ...     ...
# 296       136     1      0.0    1    0      2       0
# 297        90     0      1.0    1    2      1       0
# 298       123     1      0.2    1    0      3       0
# 299       132     0      1.2    1    0      3       0
# 300       141     0      3.4    1    2      3       0
#
# [151 rows x 7 columns]

# %%
df_main=pd.concat([df1,df2])
df_main
# Out:
#       age  sex   cp  trtbps   chol  fbs  restecg  thalachh  exng  oldpeak  \
# 1    37.0  1.0  2.0   130.0  250.0  0.0      1.0       NaN   NaN      NaN
# 2    41.0  0.0  1.0   130.0  204.0  0.0      0.0       NaN   NaN      NaN
# 3    56.0  1.0  1.0   120.0  236.0  0.0      1.0       NaN   NaN      NaN
# 4    57.0  0.0  0.0   120.0  354.0  0.0      1.0       NaN   NaN      NaN
# 5    57.0  1.0  0.0   140.0  192.0  0.0      1.0       NaN   NaN      NaN
# ..    ...  ...  ...     ...    ...  ...      ...       ...   ...      ...
# 296   NaN  NaN  NaN     NaN    NaN  NaN      NaN     136.0   1.0      0.0
# 297   NaN  NaN  NaN     NaN    NaN  NaN      NaN      90.0   0.0      1.0
# 298   NaN  NaN  NaN     NaN    NaN  NaN      NaN     123.0   1.0      0.2
# 299   NaN  NaN  NaN     NaN    NaN  NaN      NaN     132.0   0.0      1.2
# 300   NaN  NaN  NaN     NaN    NaN  NaN      NaN     141.0   0.0      3.4
#
#      slp  caa  thall  output
# 1    NaN  NaN    NaN     NaN
# ...

# %%
heart_data=pd.read_csv("heart (1).csv")

# %%
column_to_transform="restecg"

# %%
heart_data[column_to_transform]=heart_data[column_to_transform].replace({1:True,0:False})

# %%
heart_data.to_csv("transformed_heart.csv",index=False)
heart_data
# Out:
#      age  sex  cp  trtbps  chol  fbs restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1   False       150     0      2.3    0
# 1     37    1   2     130   250    0    True       187     0      3.5    0
# 2     41    0   1     130   204    0   False       172     0      1.4    2
# 3     56    1   1     120   236    0    True       178     0      0.8    2
# 4     57    0   0     120   354    0    True       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...     ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0    True       123     1      0.2    1
# 299   45    1   3     110   264    0    True       132     0      1.2    1
# 300   68    1   0     144   193    1    True       141     0      3.4    1
# 301   57    1   0     130   131    0    True       115     1      1.2    1
# 302   57    0   1     130   236    0   False       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
df["oldpeak"]=df["oldpeak"].astype(int)
df.dtypes
# Out:
# age         int64
# sex         int64
# cp          int64
# trtbps      int64
# chol        int64
# fbs         int64
# restecg     int64
# thalachh    int64
# exng        int64
# oldpeak     int64
# slp         int64
# caa         int64
# thall       int64
# output      int64
# dtype: object

# %%
df.tail()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 298   57    0   0     140   241    0        1       123     1        0    1
# 299   45    1   3     110   264    0        1       132     0        1    1
# 300   68    1   0     144   193    1        1       141     0        3    1
# 301   57    1   0     130   131    0        1       115     1        1    1
# 302   57    0   1     130   236    0        0       174     0        0    1
#
#      caa  thall  output
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0

# %%
df.groupby("output").mean()
# Out:
#               age       sex        cp      trtbps        chol       fbs  \
# output
# 0       56.601449  0.826087  0.478261  134.398551  251.086957  0.159420
# 1       52.496970  0.563636  1.375758  129.303030  242.230303  0.139394
#
#          restecg    thalachh      exng   oldpeak       slp       caa     thall
# output
# 0       0.449275  139.101449  0.550725  1.260870  1.166667  1.166667  2.543478
# 1       0.593939  158.466667  0.139394  0.351515  1.593939  0.363636  2.121212

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0        2    0
# 1   37    1   2     130   250    0        1       187     0        3    0
# 2   41    0   1     130   204    0        0       172     0        1    2
# 3   56    1   1     120   236    0        1       178     0        0    2
# 4   57    0   0     120   354    0        1       163     1        0    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df["caa"].unique()
# Out:
# array([0, 2, 1, 3, 4])

# %%
df.caa.value_counts()
# Out:
# caa
# 0    175
# 1     65
# 2     38
# 3     20
# 4      5
# Name: count, dtype: int64

# %%
df.count()
# Out:
# age         303
# sex         303
# cp          303
# trtbps      303
# chol        303
# fbs         303
# restecg     303
# thalachh    303
# exng        303
# oldpeak     303
# slp         303
# caa         303
# thall       303
# output      303
# dtype: int64

# %%
heart_data=pd.read_csv("heart (1).csv")

# %%
x="age"
y="chol"

# %%
plt.scatter(heart_data[x],heart_data[y],color='skyblue')
plt.title(f"Scatter plot between {x} and {y}")
plt.xlabel(x)
plt.ylabel(y)
plt.grid(True)
plt.show()
